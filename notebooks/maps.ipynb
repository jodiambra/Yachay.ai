# %%
import os
import json
import pandas as pd
import plotly_express as px
import numpy as np  
import re

# %%
coords = pd.read_csv('data/Clusters_Coordinates.csv')

# %%
coords.head()
# Out:
#    cluster_id        lat         lng                    coords
# 0           2  34.020789 -118.411907  34.0207895, -118.4119065
# 1           3  31.168893 -100.076888  31.1688935, -100.0768885
# 2           8  29.838495  -95.446487   29.8384948, -95.4464865
# 3           9  40.780709  -73.968542    40.780709, -73.9685415
# 4          16  40.004866  -75.117998    40.0048655, -75.117998

# %%
px.scatter_geo(coords, lat='lat', lon='lng', width=1400, height=900, opacity=.6, scope='north america', projection='stereographic')

# %%
px.density_mapbox(coords, lat='lat', lon='lng', center=dict(lat=40, lon=-100), zoom=2.5, mapbox_style='carto-darkmatter', width=1400, height=900)
